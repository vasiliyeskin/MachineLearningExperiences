# %% [markdown]
# <a href="https://colab.research.google.com/github/vasiliyeskin/MachineLearningExperiences/blob/master/pretrained_networks/vgg19_object_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Использование предобученной нейронной сети**

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
# Создаем модель с архитектурой VGG16 и загружаем веса, обученные
# на наборе данных ImageNet
model = VGG16(weights='imagenet')
# Out:
# ...
# 553467904/553467096 [==============================] - 4s 0us/step

# %%
# !wget https://github.com/vasiliyeskin/MachineLearningExperiences/raw/master/pretrained_networks/alien.jpg -O alien.jpg
# !wget https://github.com/vasiliyeskin/MachineLearningExperiences/raw/master/pretrained_networks/cat.jpg -O cat.jpg
# !wget https://github.com/vasiliyeskin/MachineLearningExperiences/raw/master/pretrained_networks/ship.jpg -O ship.jpg
# !wget https://github.com/vasiliyeskin/MachineLearningExperiences/raw/master/pretrained_networks/plane.jpg -O plane.jpg
# !wget https://github.com/vasiliyeskin/MachineLearningExperiences/raw/master/pretrained_networks/stranger.jpg -O stranger.jpg

# %%
ls
# Out:
# alien.jpg  cat.jpg  plane.jpg  sample_data/  ship.jpg  stranger.jpg

# %%
# Загружаем изображение для распознавания, преобразовываем его в массив
# numpy и выполняем предварительную обработку
# img_path = 'cat.jpg'
img_path = 'ship.jpg'
# img_path = 'plane.jpg'
# img_path = 'alien.jpg'
# img_path = 'stranger.jpg'

Image(img_path, width=150, height=150)

# %%
img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img, cmap='gray')
plt.show()

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Запускаем распознавание объекта на изображении
preds = model.predict(x)

# %%
# Печатаем три класса объекта с самой высокой вероятностью
print('Результаты распознавания:', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания: [('n04147183', 'schooner', 0.55734247), ('n04612504', 'yawl', 0.25635076), ('n02981792', 'catamaran', 0.09470453)]
